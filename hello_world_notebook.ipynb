# %% [markdown]
# <a href="https://colab.research.google.com/github/singhaparnach-ship-it/myPublicRepo/blob/myFirstGoogleColabNoteBook/hello_world_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is the first Google Colab Notebook!
# Print a message

# %%
print ("Hello World")
# Out:
# Hello World

# %% [markdown]
# Ask for user name and print a message

# %%
name = input("What is your name?")
print ("Hello " + name)
print ("Congratulations on creating your first Colab Notebook!")
print ("Do you know that your name contains " + str(len(name)) + " characters?")
# Out:
# What is your name?Aparna
# Hello Aparna
# Congratulations on creating your first Colab Notebook!
# Do you know that your name contains 6 characters?

# %% [markdown]
# **Print a pyramid of input charater **

# %%
char = input("Enter a character: ")

if len(char) != 1:
    print("Please enter a single character.")
else:
    for i in range(1, 6):
        print(char * i)
# Out:
# Enter a character: /
# /
# //
# ///
# ////
# /////
